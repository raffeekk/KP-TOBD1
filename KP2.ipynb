# %%
import pandas as pd
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Загрузка набора данных
df = pd.read_csv('/content/diabetes_dataset (1).csv')

# Обработка категориальных признаков
categorical_cols = df.select_dtypes(include='object').columns
df_encoded = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# Разделение на признаки и целевую переменную
X = df_encoded.drop('diagnosed_diabetes', axis=1)
y = df_encoded['diagnosed_diabetes']

# Применение PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)
principal_df = pd.DataFrame(data=principal_components, columns=['principal_component_1', 'principal_component_2'])

# Визуализация результатов PCA
plt.figure(figsize=(10, 8))
sns.scatterplot(x=principal_df['principal_component_1'], y=principal_df['principal_component_2'], hue=y)
plt.title('PCA набора данных о диабете')
plt.xlabel('Главная компонента 1')
plt.ylabel('Главная компонента 2')
plt.show()
